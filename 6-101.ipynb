# %%
import pandas as pd
import numpy as np 
import json
import csv


import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import tqdm_notebook as tqdm

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.stem import WordNetLemmatizer 
import nltk
nltk.download('averaged_perceptron_tagger')

import spacy
import math

import string
import sys
import random

from collections import Counter
from itertools import chain

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/aarunku5/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
df_testgood=pd.read_csv("./test_good_101_1.csv")
glabel=pd.read_csv("./test_good_101_1_words.csv")

ge=pd.read_csv('./test_good_101_1_wordse.csv')
gn=pd.read_csv('./test_good_101_1_wordsn.csv')
gc=pd.read_csv('./test_good_101_1_wordsc.csv')

print(len(ge))
print(len(gn))
print(len(gc))

nlp = spacy.load("en_trf_bertbaseuncased_lg")
# Out:
# 48
# 104
# 50

# %%
data = ge['fullnopunc'].to_list()
dff = pd.DataFrame(data,columns=['sentence'])
dff = dff.dropna(thresh=1)
m1=[]
xx=[]

for i in range(1000):
    df=dff.sample(frac=random.random())
    count = df['sentence'].value_counts() 
    x=count.value_counts(normalize=True)
    x.sort_index()
    z=x.index
    y=[]
    for j in range(1,2):
        if j in z:
            y.append(x[j])
        else:
            y.append(0)       
    m1.append(y[0])
    xx.append(len(count))    
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(xx,m1,c='green')
ax.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.show()
plt.clf()

print("T1")

print(pd.Series(m1).std())
print(pd.Series(m1).var())

count = dff['sentence'].value_counts() 
count.sort_values(ascending=False)
print(count.value_counts(normalize=True))

sentencestd=(count/len(count)).std()
print(1/sentencestd)

print("T2")

nr=len(ge)
print(nr)
dr=0
for i in range(len(count)):
    xdr=(2-count[i])
    if(xdr>0):
        dr=dr+count[i]
    else:
        dr=dr-count[i]
print(dr)
print(dr/nr)
# Out:
# T1
# 0.07726558075864001
# 0.0059699699699699215
# 1    1.0
# Name: sentence, dtype: float64
# 7.130304346460502e+16
# T2
# 48
# 48
# 1.0

# %%
data = gn['fullnopunc'].to_list()
dff = pd.DataFrame(data,columns=['sentence'])
dff = dff.dropna(thresh=1)
m1=[]
m2=[]
xx=[]

for i in range(1000):
    df=dff.sample(frac=random.random())
    count = df['sentence'].value_counts() 
    x=count.value_counts(normalize=True)
    x.sort_index()
    z=x.index
    y=[]
    for j in range(1,3):
        if j in z:
            y.append(x[j])
        else:
            y.append(0)       
    m1.append(y[0])
    m2.append(y[1])
    xx.append(len(count))    
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(xx,m1,c='green')
ax.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.show()
plt.clf()
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(xx,m2,c='blue')
ax.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.show()
plt.clf()

print("T1")

print(pd.Series(m1).std())
print(pd.Series(m2).std())
print(pd.Series(m1).var())
print(pd.Series(m2).var())

count = dff['sentence'].value_counts() 
count.sort_values(ascending=False)
print(count.value_counts(normalize=True))

sentencestd=(count/len(count)).std()
print(1/sentencestd)

print("T2")

nr=len(ge)
print(nr)
dr=0
for i in range(len(count)):
    xdr=(2-count[i])
    if(xdr>0):
        dr=dr+count[i]
    else:
        dr=dr-count[i]
print(dr)
print(dr/nr)
# Out:
# T1
# 0.07724008088217614
# 0.00731343777608966
# 0.005966030094685112
# 5.348637210473527e-05
# 1    0.990291
# 2    0.009709
# Name: sentence, dtype: float64
# 1045.3358312045007
# T2
# 48
# 100
# 2.0833333333333335

# %%
data = gc['fullnopunc'].to_list()
dff = pd.DataFrame(data,columns=['sentence'])
dff = dff.dropna(thresh=1)
m1=[]
xx=[]

for i in range(1000):
    df=dff.sample(frac=random.random())
    count = df['sentence'].value_counts() 
    x=count.value_counts(normalize=True)
    x.sort_index()
    z=x.index
    y=[]
    for j in range(1,2):
        if j in z:
            y.append(x[j])
        else:
            y.append(0)       
    m1.append(y[0])
    xx.append(len(count))    
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(xx,m1,c='green')
ax.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.show()
plt.clf()

print("T1")

print(pd.Series(m1).std())
print(pd.Series(m1).var())

count = dff['sentence'].value_counts() 
count.sort_values(ascending=False)
print(count.value_counts(normalize=True))

sentencestd=(count/len(count)).std()
print(1/sentencestd)

print("T2")

nr=len(ge)
print(nr)
dr=0
for i in range(len(count)):
    xdr=(2-count[i])
    if(xdr>0):
        dr=dr+count[i]
    else:
        dr=dr-count[i]
print(dr)
print(dr/nr)
# Out:
# T1
# 0.12161327966052882
# 0.014789789789789993
# 1    1.0
# Name: sentence, dtype: float64
# 1.426667574645773e+17
# T2
# 48
# 50
# 1.0416666666666667

# %%
count = glabel['fullnopunc'].value_counts() 
df=pd.DataFrame()
df['sentence']=count.index
arrsd=[]
for i in tqdm(range(len(df))):
    arr=[]
    c1=0
    c2=0
    c3=0
    s=df.iloc[i]['sentence']
    x=ge['fullnopunc'].str.findall(s)
    c1=len(x.sum())
    x=gn['fullnopunc'].str.findall(s)
    c2=len(x.sum())
    x=gc['fullnopunc'].str.findall(s)
    c3=len(x.sum())
    if(c1+c2+c3>1):
        arr.append(c1)
        arr.append(c2)
        arr.append(c3)
        sd=pd.Series(arr).std()
        arrsd.append(sd)
    else:
        arrsd.append(0)        
print(len(glabel)/(pd.Series(arrsd).sum()+1))
# Out:
# HBox(children=(IntProgress(value=0, max=201), HTML(value='')))
# 93.74852625782643

# %%
magwordsge=ge.final.str.split(expand=True).stack().value_counts()
magwordsgn=gn.final.str.split(expand=True).stack().value_counts()
magwordsgc=gc.final.str.split(expand=True).stack().value_counts()

# %%
genw=(magwordsge/len(magwordsge))
gnnw=(magwordsgn/len(magwordsgn))
gcnw=(magwordsgc/len(magwordsgc))

# %%
print(1/genw.std())
print(1/gnnw.std())
print(1/gcnw.std())
# Out:
# 113.47475470500795
# 136.55567876758388
# 103.70672464782773

# %%
nrge=magwordsge.sum() 
print(nrge)
drge=0
for i in range(len(magwordsge)):
    xdr=((0.01*nrge)-magwordsge[i])*(magwordsge[i]-1)
    if(xdr>=0):
        drge=drge+magwordsge[i]
    else:
        drge=drge-magwordsge[i]
print(drge)
print(drge/nrge)
print((magwordsge/nrge).head(6))
# Out:
# 310
# 172
# 0.5548387096774193
# man        0.054839
# woman      0.045161
# men        0.016129
# sitting    0.016129
# boy        0.012903
# two        0.012903
# dtype: float64

# %%
nrgn=magwordsgn.sum() 
print(nrgn)
drgn=0
for i in range(len(magwordsgn)):
    xdr=((0.01*nrgn)-magwordsgn[i])*(magwordsgn[i]-1)
    if(xdr>=0):
        drgn=drgn+magwordsgn[i]
    else:
        drgn=drgn-magwordsgn[i]
print(drgn)
print(drgn/nrgn)
print((magwordsgn/nrgn).head(6))
# Out:
# 641
# 423
# 0.6599063962558502
# man        0.059282
# woman      0.029641
# people     0.020281
# wearing    0.012480
# sitting    0.012480
# black      0.012480
# dtype: float64

# %%
nrgc=magwordsgc.sum() 
print(nrgc)
drgc=0
for i in range(len(magwordsgc)):
    xdr=((0.01*nrgc)-magwordsgc[i])*(magwordsgc[i]-1)
    if(xdr>=0):
        drgc=drgc+magwordsgc[i]
    else:
        drgc=drgc-magwordsgc[i]
print(drgc)
print(drgc/nrgc)
print((magwordsgc/nrgc).head(6))
# Out:
# 343
# 179
# 0.521865889212828
# man      0.064140
# woman    0.037901
# child    0.023324
# two      0.020408
# shirt    0.017493
# red      0.014577
# dtype: float64

# %%
magwordsg=glabel.final.str.split(expand=True).stack().value_counts()

# %%
df=pd.DataFrame()
df['sentence']=magwordsg.index
arrsd=[]
for i in tqdm(range(len(df))):
    arr=[]
    c1=0
    c2=0
    c3=0
    s=df.iloc[i]['sentence']
    for j in range(len(ge)):
        ss=ge.iloc[j]['fullnopunc']
        ss=ss.split()
        c1=c1+ss.count(s)
    for j in range(len(gn)):
        ss=gn.iloc[j]['fullnopunc']
        ss=ss.split()
        c2=c2+ss.count(s)
    for j in range(len(gc)):
        ss=gc.iloc[j]['fullnopunc']
        ss=ss.split()
        c3=c3+ss.count(s)
    if(c1+c2+c3>1):
        arr.append(c1)
        arr.append(c2)
        arr.append(c3)
        sd=pd.Series(arr).std()
        arrsd.append(sd)
    else:
        arrsd.append(0)
gstd=arrsd
print(len(magwordsg)/(pd.Series(gstd).sum()+1))
# Out:
# HBox(children=(IntProgress(value=0, max=585), HTML(value='')))
# 2.4508693232453775

# %%
tagged=nltk.pos_tag(magwordsge.index)
tagged
tagged_reduced_adjective = set()
tagged_reduced_verbs = set()
tagged_reduced_adverbs = set()
tagged_reduced_nouns = set()
for speech_tag in tagged:
    if speech_tag[1] in ['JJ','JJR','JJS']:
        tagged_reduced_adjective.add(speech_tag[0])
    elif speech_tag[1] in ['RB','RBR','RBS']:
        tagged_reduced_adverbs.add(speech_tag[0])
    elif speech_tag[1] in ['VB','VBD','VBG','VBN','VBP','VBZ']:
        tagged_reduced_verbs.add(speech_tag[0])
    elif speech_tag[1] in ['NN','NNS','NNP','NNPS']:
        tagged_reduced_nouns.add(speech_tag[0])
        
print("ADJ")
arr=np.zeros(shape=(len(tagged_reduced_adjective)))
j=0
for w in (tagged_reduced_adjective):
    for i in range(len(magwordsge)):
        if(magwordsge.index[i]==w):
            arr[j]=magwordsge[i]
            j=j+1
narr=(arr/len(arr))
adjvar=narr.std()
print(1/adjvar)

nr=arr.sum() 
print(nr)
dr=0
for i in range(len(arr)):
    xdr=((0.02*nr)-arr[i])*(arr[i]-1)
    if(xdr>=0):
        dr=dr+arr[i]
    else:
        dr=dr-arr[i]
print(dr)
print(dr/nr)

print(pd.Series(arr/nr).sort_values(ascending=False).head(20))
print(len(arr))


#------------------------------------------------------
print("ADV")
arr=np.zeros(shape=(len(tagged_reduced_adverbs)))
j=0
for w in (tagged_reduced_adverbs):
    for i in range(len(magwordsge)):
        if(magwordsge.index[i]==w):
            arr[j]=magwordsge[i]
            j=j+1
narr=(arr/len(arr))
advvar=narr.std()
print(1/advvar)

nr=arr.sum() 
print(nr)
dr=0
for i in range(len(arr)):
    xdr=((0.03*nr)-arr[i])*(arr[i]-1)
    if(xdr>=0):
        dr=dr+arr[i]
    else:
        dr=dr-arr[i]
print(dr)
print(dr/nr)

print(pd.Series(arr/nr).sort_values(ascending=False).head(20))
print(len(arr))


#------------------------------------------------------
print("VERB")
arr=np.zeros(shape=(len(tagged_reduced_verbs)))
j=0
for w in (tagged_reduced_verbs):
    for i in range(len(magwordsge)):
        if(magwordsge.index[i]==w):
            arr[j]=magwordsge[i]
            j=j+1
narr=(arr/len(arr))
verbvar=narr.std()
print(1/verbvar)

nr=arr.sum() 
print(nr)
dr=0
for i in range(len(arr)):
    xdr=((0.01*nr)-arr[i])*(arr[i]-1)
    if(xdr>=0):
        dr=dr+arr[i]
    else:
        dr=dr-arr[i]
print(dr)
print(dr/nr)

print(pd.Series(arr/nr).sort_values(ascending=False).head(20))
print(len(arr))


#------------------------------------------------------
print("NOUN")
arr=np.zeros(shape=(len(tagged_reduced_nouns)))
j=0
for w in (tagged_reduced_nouns):
    for i in range(len(magwordsge)):
        if(magwordsge.index[i]==w):
            arr[j]=magwordsge[i]
            j=j+1
narr=(arr/len(arr))
nounvar=narr.std()
print(1/nounvar)

nr=arr.sum() 
print(nr)
dr=0
for i in range(len(arr)):
    xdr=((0.01*nr)-arr[i])*(arr[i]-1)
    if(xdr>=0):
        dr=dr+arr[i]
    else:
        dr=dr-arr[i]
print(dr)
print(dr/nr)

print(pd.Series(arr/nr).sort_values(ascending=False).head(20))
print(len(arr))
# Out:
# ADJ
# 74.66754814921332
# 66.0
# 6.0
# 0.09090909090909091
# 39    0.060606
# 29    0.045455
# 5     0.045455
# 14    0.030303
# 15    0.030303
# 6     0.030303
# 37    0.030303
# 31    0.030303
# 41    0.030303
# 42    0.030303
# 44    0.030303
# 2     0.030303
# 18    0.030303
# 16    0.015152
# 17    0.015152
# 13    0.015152
# 12    0.015152
# 48    0.015152
# 8     0.015152
# 11    0.015152
# dtype: float64
# 49
# ADV
# 3.602879701896397e+16
# 7.0
# 7.0
# 1.0
# 6    0.142857
# 5    0.142857
# 4    0.142857
# 3    0.142857
# 2    0.142857
# 1    0.142857
# 0    0.142857
# dtype: float64
# 7
# VERB
# 40.36960759521083
# 58.0
# -12.0
# -0.20689655172413793
# 4     0.086207
# 23    0.068966
# 3     0.051724
# 29    0.051724
# 18    0.034483
# 2     0.034483
# 5     0.034483
# 6     0.034483
# 12    0.034483
# 14    0.034483
# 19    0.034483
# 0     0.034483
# 32    0.034483
# 27    0.034483
# 24    0.017241
# 11    0.017241
# 1     0.017241
# 34    0.017241
# 33    0.017241
# 31    0.017241
# dtype: float64
# 37
# NOUN
# 38.3025762782591
# 164.0
# -60.0
# -0.36585365853658536
# 78    0.103659
# 43    0.085366
# 80    0.030488
# 17    0.024390
# 49    0.024390
# 57    0.024390
# 0     0.024390
# 46    0.018293
# 35    0.018293
# 3     0.018293
# 4     0.018293
# 55    0.012195
# 18    0.012195
# 51    0.012195
# 83    0.012195
# 20    0.012195
# 47    0.012195
# 23    0.012195
# 21    0.012195
# 60    0.012195
# dtype: float64
# 87

# %%
tagged=nltk.pos_tag(magwordsgn.index)
tagged
tagged_reduced_adjective = set()
tagged_reduced_verbs = set()
tagged_reduced_adverbs = set()
tagged_reduced_nouns = set()
for speech_tag in tagged:
    if speech_tag[1] in ['JJ','JJR','JJS']:
        tagged_reduced_adjective.add(speech_tag[0])
    elif speech_tag[1] in ['RB','RBR','RBS']:
        tagged_reduced_adverbs.add(speech_tag[0])
    elif speech_tag[1] in ['VB','VBD','VBG','VBN','VBP','VBZ']:
        tagged_reduced_verbs.add(speech_tag[0])
    elif speech_tag[1] in ['NN','NNS','NNP','NNPS']:
        tagged_reduced_nouns.add(speech_tag[0])
        
print("ADJ")
arr=np.zeros(shape=(len(tagged_reduced_adjective)))
j=0
for w in (tagged_reduced_adjective):
    for i in range(len(magwordsgn)):
        if(magwordsgn.index[i]==w):
            arr[j]=magwordsgn[i]
            j=j+1
narr=(arr/len(arr))
adjvar=narr.std()
print(1/adjvar)

nr=arr.sum() 
print(nr)
dr=0
for i in range(len(arr)):
    xdr=((0.02*nr)-arr[i])*(arr[i]-1)
    if(xdr>=0):
        dr=dr+arr[i]
    else:
        dr=dr-arr[i]
print(dr)
print(dr/nr)

print(pd.Series(arr/nr).sort_values(ascending=False).head(20))
print(len(arr))


#------------------------------------------------------
print("ADV")
arr=np.zeros(shape=(len(tagged_reduced_adverbs)))
j=0
for w in (tagged_reduced_adverbs):
    for i in range(len(magwordsgn)):
        if(magwordsgn.index[i]==w):
            arr[j]=magwordsgn[i]
            j=j+1
narr=(arr/len(arr))
advvar=narr.std()
print(1/advvar)

nr=arr.sum() 
print(nr)
dr=0
for i in range(len(arr)):
    xdr=((0.03*nr)-arr[i])*(arr[i]-1)
    if(xdr>=0):
        dr=dr+arr[i]
    else:
        dr=dr-arr[i]
print(dr)
print(dr/nr)

print(pd.Series(arr/nr).sort_values(ascending=False).head(20))
print(len(arr))


#------------------------------------------------------
print("VERB")
arr=np.zeros(shape=(len(tagged_reduced_verbs)))
j=0
for w in (tagged_reduced_verbs):
    for i in range(len(magwordsgn)):
        if(magwordsgn.index[i]==w):
            arr[j]=magwordsgn[i]
            j=j+1
narr=(arr/len(arr))
verbvar=narr.std()
print(1/verbvar)

nr=arr.sum() 
print(nr)
dr=0
for i in range(len(arr)):
    xdr=((0.01*nr)-arr[i])*(arr[i]-1)
    if(xdr>=0):
        dr=dr+arr[i]
    else:
        dr=dr-arr[i]
print(dr)
print(dr/nr)

print(pd.Series(arr/nr).sort_values(ascending=False).head(20))
print(len(arr))


#------------------------------------------------------
print("NOUN")
arr=np.zeros(shape=(len(tagged_reduced_nouns)))
j=0
for w in (tagged_reduced_nouns):
    for i in range(len(magwordsgn)):
        if(magwordsgn.index[i]==w):
            arr[j]=magwordsgn[i]
            j=j+1
narr=(arr/len(arr))
nounvar=narr.std()
print(1/nounvar)

nr=arr.sum() 
print(nr)
dr=0
for i in range(len(arr)):
    xdr=((0.01*nr)-arr[i])*(arr[i]-1)
    if(xdr>=0):
        dr=dr+arr[i]
    else:
        dr=dr-arr[i]
print(dr)
print(dr/nr)

print(pd.Series(arr/nr).sort_values(ascending=False).head(20))
print(len(arr))
# Out:
# ADJ
# 50.80078571393395
# 120.0
# 18.0
# 0.15
# 63    0.066667
# 20    0.058333
# 21    0.050000
# 31    0.041667
# 25    0.033333
# 32    0.033333
# 55    0.033333
# 72    0.033333
# 4     0.025000
# 38    0.025000
# 26    0.025000
# 68    0.016667
# 49    0.016667
# 18    0.016667
# 6     0.016667
# 71    0.016667
# 9     0.016667
# 46    0.016667
# 28    0.008333
# 27    0.008333
# dtype: float64
# 73
# ADV
# 16.41409700974017
# 26.0
# -2.0
# -0.07692307692307693
# 4     0.192308
# 6     0.115385
# 7     0.076923
# 14    0.076923
# 1     0.076923
# 16    0.038462
# 2     0.038462
# 3     0.038462
# 5     0.038462
# 8     0.038462
# 15    0.038462
# 9     0.038462
# 10    0.038462
# 11    0.038462
# 12    0.038462
# 13    0.038462
# 0     0.038462
# dtype: float64
# 17
# VERB
# 48.5430162337919
# 118.0
# -18.0
# -0.15254237288135594
# 20    0.067797
# 6     0.067797
# 12    0.050847
# 26    0.042373
# 60    0.042373
# 52    0.025424
# 22    0.025424
# 62    0.025424
# 57    0.025424
# 23    0.016949
# 18    0.016949
# 17    0.016949
# 15    0.016949
# 48    0.016949
# 13    0.016949
# 0     0.016949
# 31    0.016949
# 55    0.016949
# 56    0.016949
# 7     0.016949
# dtype: float64
# 71
# NOUN
# 52.77850920976191
# 348.0
# 104.0
# 0.2988505747126437
# 154    0.109195
# 104    0.054598
# 122    0.037356
# 0      0.017241
# 158    0.017241
# 108    0.014368
# 155    0.014368
# 78     0.014368
# 130    0.014368
# 74     0.011494
# 98     0.011494
# 38     0.011494
# 94     0.011494
# 45     0.011494
# 127    0.008621
# 1      0.008621
# 116    0.008621
# 12     0.008621
# 13     0.008621
# 101    0.008621
# dtype: float64
# 175

# %%
tagged=nltk.pos_tag(magwordsgc.index)
tagged
tagged_reduced_adjective = set()
tagged_reduced_verbs = set()
tagged_reduced_adverbs = set()
tagged_reduced_nouns = set()
for speech_tag in tagged:
    if speech_tag[1] in ['JJ','JJR','JJS']:
        tagged_reduced_adjective.add(speech_tag[0])
    elif speech_tag[1] in ['RB','RBR','RBS']:
        tagged_reduced_adverbs.add(speech_tag[0])
    elif speech_tag[1] in ['VB','VBD','VBG','VBN','VBP','VBZ']:
        tagged_reduced_verbs.add(speech_tag[0])
    elif speech_tag[1] in ['NN','NNS','NNP','NNPS']:
        tagged_reduced_nouns.add(speech_tag[0])
        
print("ADJ")
arr=np.zeros(shape=(len(tagged_reduced_adjective)))
j=0
for w in (tagged_reduced_adjective):
    for i in range(len(magwordsgc)):
        if(magwordsgc.index[i]==w):
            arr[j]=magwordsgc[i]
            j=j+1
narr=(arr/len(arr))
adjvar=narr.std()
print(1/adjvar)

nr=arr.sum() 
print(nr)
dr=0
for i in range(len(arr)):
    xdr=((0.02*nr)-arr[i])*(arr[i]-1)
    if(xdr>=0):
        dr=dr+arr[i]
    else:
        dr=dr-arr[i]
print(dr)
print(dr/nr)

print(pd.Series(arr/nr).sort_values(ascending=False).head(20))
print(len(arr))


#------------------------------------------------------
print("ADV")
arr=np.zeros(shape=(len(tagged_reduced_adverbs)))
j=0
for w in (tagged_reduced_adverbs):
    for i in range(len(magwordsgc)):
        if(magwordsgc.index[i]==w):
            arr[j]=magwordsgc[i]
            j=j+1
narr=(arr/len(arr))
advvar=narr.std()
print(1/advvar)

nr=arr.sum() 
print(nr)
dr=0
for i in range(len(arr)):
    xdr=((0.03*nr)-arr[i])*(arr[i]-1)
    if(xdr>=0):
        dr=dr+arr[i]
    else:
        dr=dr-arr[i]
print(dr)
print(dr/nr)

print(pd.Series(arr/nr).sort_values(ascending=False).head(20))
print(len(arr))


#------------------------------------------------------
print("VERB")
arr=np.zeros(shape=(len(tagged_reduced_verbs)))
j=0
for w in (tagged_reduced_verbs):
    for i in range(len(magwordsgc)):
        if(magwordsgc.index[i]==w):
            arr[j]=magwordsgc[i]
            j=j+1
narr=(arr/len(arr))
verbvar=narr.std()
print(1/verbvar)

nr=arr.sum() 
print(nr)
dr=0
for i in range(len(arr)):
    xdr=((0.01*nr)-arr[i])*(arr[i]-1)
    if(xdr>=0):
        dr=dr+arr[i]
    else:
        dr=dr-arr[i]
print(dr)
print(dr/nr)

print(pd.Series(arr/nr).sort_values(ascending=False).head(20))
print(len(arr))


#------------------------------------------------------
print("NOUN")
arr=np.zeros(shape=(len(tagged_reduced_nouns)))
j=0
for w in (tagged_reduced_nouns):
    for i in range(len(magwordsgc)):
        if(magwordsgc.index[i]==w):
            arr[j]=magwordsgc[i]
            j=j+1
narr=(arr/len(arr))
nounvar=narr.std()
print(1/nounvar)

nr=arr.sum() 
print(nr)
dr=0
for i in range(len(arr)):
    xdr=((0.01*nr)-arr[i])*(arr[i]-1)
    if(xdr>=0):
        dr=dr+arr[i]
    else:
        dr=dr-arr[i]
print(dr)
print(dr/nr)

print(pd.Series(arr/nr).sort_values(ascending=False).head(20))
print(len(arr))
# Out:
# ADJ
# 57.007112157185276
# 61.0
# 1.0
# 0.01639344262295082
# 0     0.065574
# 35    0.049180
# 27    0.049180
# 4     0.049180
# 8     0.049180
# 2     0.032787
# 6     0.032787
# 40    0.032787
# 9     0.032787
# 28    0.032787
# 1     0.032787
# 38    0.032787
# 5     0.016393
# 7     0.016393
# 18    0.016393
# 3     0.016393
# 10    0.016393
# 11    0.016393
# 12    0.016393
# 13    0.016393
# dtype: float64
# 43
# ADV
# 6.3639610306789285
# 4.0
# 0.0
# 0.0
# 2    0.50
# 1    0.25
# 0    0.25
# dtype: float64
# 3
# VERB
# 29.91946837780559
# 79.0
# -19.0
# -0.24050632911392406
# 26    0.101266
# 13    0.063291
# 36    0.063291
# 30    0.050633
# 10    0.050633
# 1     0.037975
# 14    0.037975
# 15    0.037975
# 16    0.037975
# 23    0.037975
# 21    0.025316
# 5     0.025316
# 27    0.025316
# 0     0.025316
# 29    0.012658
# 28    0.012658
# 41    0.012658
# 2     0.012658
# 3     0.012658
# 4     0.012658
# dtype: float64
# 44
# NOUN
# 39.48787504997369
# 173.0
# -45.0
# -0.26011560693641617
# 88    0.127168
# 56    0.075145
# 39    0.034682
# 72    0.023121
# 74    0.017341
# 42    0.017341
# 90    0.017341
# 49    0.017341
# 61    0.011561
# 17    0.011561
# 20    0.011561
# 64    0.011561
# 63    0.011561
# 21    0.011561
# 18    0.011561
# 25    0.011561
# 75    0.011561
# 33    0.011561
# 35    0.011561
# 43    0.011561
# dtype: float64
# 98

# %%
tagged=nltk.pos_tag(magwordsg.index)
tagged
tagged_reduced_adjective = set()
tagged_reduced_verbs = set()
tagged_reduced_adverbs = set()
tagged_reduced_nouns = set()
for speech_tag in tagged:
    if speech_tag[1] in ['JJ','JJR','JJS']:
        tagged_reduced_adjective.add(speech_tag[0])
    elif speech_tag[1] in ['RB','RBR','RBS']:
        tagged_reduced_adverbs.add(speech_tag[0])
    elif speech_tag[1] in ['VB','VBD','VBG','VBN','VBP','VBZ']:
        tagged_reduced_verbs.add(speech_tag[0])
    elif speech_tag[1] in ['NN','NNS','NNP','NNPS']:
        tagged_reduced_nouns.add(speech_tag[0])

# %%
df=pd.DataFrame(data=tagged_reduced_adjective,columns=['sentence'])
df
arrsd=[]
for i in tqdm(range(len(df))):
    arr=[]
    c1=0
    c2=0
    c3=0
    s=df.iloc[i]['sentence']
    for j in range(len(ge)):
        ss=ge.iloc[j]['fullnopunc']
        ss=ss.split()
        c1=c1+ss.count(s)
    for j in range(len(gn)):
        ss=gn.iloc[j]['fullnopunc']
        ss=ss.split()
        c2=c2+ss.count(s)
    for j in range(len(gc)):
        ss=gc.iloc[j]['fullnopunc']
        ss=ss.split()
        c3=c3+ss.count(s)
    if(c1+c2+c3>1):
        arr.append(c1)
        arr.append(c2)
        arr.append(c3)
        sd=pd.Series(arr).std()
        arrsd.append(sd)
    else:
        arrsd.append(0)
gadjstd=arrsd
print(len(df)/(pd.Series(arrsd).sum()+1))
# Out:
# HBox(children=(IntProgress(value=0, max=131), HTML(value='')))
# 2.868534652066023

# %%
df=pd.DataFrame(data=tagged_reduced_adverbs,columns=['sentence'])
df
arrsd=[]
for i in tqdm(range(len(df))):
    arr=[]
    c1=0
    c2=0
    c3=0
    s=df.iloc[i]['sentence']
    for j in range(len(ge)):
        ss=ge.iloc[j]['fullnopunc']
        ss=ss.split()
        c1=c1+ss.count(s)
    for j in range(len(gn)):
        ss=gn.iloc[j]['fullnopunc']
        ss=ss.split()
        c2=c2+ss.count(s)
    for j in range(len(gc)):
        ss=gc.iloc[j]['fullnopunc']
        ss=ss.split()
        c3=c3+ss.count(s)
    if(c1+c2+c3>1):
        arr.append(c1)
        arr.append(c2)
        arr.append(c3)
        sd=pd.Series(arr).std()
        arrsd.append(sd)
    else:
        arrsd.append(0)
gadjstd=arrsd
print(len(df)/(pd.Series(arrsd).sum()+1))
# Out:
# HBox(children=(IntProgress(value=0, max=21), HTML(value='')))
# 3.0035927918038747

# %%
df=pd.DataFrame(data=tagged_reduced_verbs,columns=['sentence'])
df
arrsd=[]
for i in tqdm(range(len(df))):
    arr=[]
    c1=0
    c2=0
    c3=0
    s=df.iloc[i]['sentence']
    for j in range(len(ge)):
        ss=ge.iloc[j]['fullnopunc']
        ss=ss.split()
        c1=c1+ss.count(s)
    for j in range(len(gn)):
        ss=gn.iloc[j]['fullnopunc']
        ss=ss.split()
        c2=c2+ss.count(s)
    for j in range(len(gc)):
        ss=gc.iloc[j]['fullnopunc']
        ss=ss.split()
        c3=c3+ss.count(s)
    if(c1+c2+c3>1):
        arr.append(c1)
        arr.append(c2)
        arr.append(c3)
        sd=pd.Series(arr).std()
        arrsd.append(sd)
    else:
        arrsd.append(0)
gadjstd=arrsd
print(len(df)/(pd.Series(arrsd).sum()+1))
# Out:
# HBox(children=(IntProgress(value=0, max=116), HTML(value='')))
# 2.472757709960418

# %%
df=pd.DataFrame(data=tagged_reduced_nouns,columns=['sentence'])
df
arrsd=[]
for i in tqdm(range(len(df))):
    arr=[]
    c1=0
    c2=0
    c3=0
    s=df.iloc[i]['sentence']
    for j in range(len(ge)):
        ss=ge.iloc[j]['fullnopunc']
        ss=ss.split()
        c1=c1+ss.count(s)
    for j in range(len(gn)):
        ss=gn.iloc[j]['fullnopunc']
        ss=ss.split()
        c2=c2+ss.count(s)
    for j in range(len(gc)):
        ss=gc.iloc[j]['fullnopunc']
        ss=ss.split()
        c3=c3+ss.count(s)
    if(c1+c2+c3>1):
        arr.append(c1)
        arr.append(c2)
        arr.append(c3)
        sd=pd.Series(arr).std()
        arrsd.append(sd)
    else:
        arrsd.append(0)
gadjstd=arrsd
print(len(df)/(pd.Series(arrsd).sum()+1))
# Out:
# HBox(children=(IntProgress(value=0, max=288), HTML(value='')))
# 2.491644539340983

# %%
data = ge['fullnopunc'].to_list()
def find_ngrams(input_list, n):
    return list(zip(*[input_list[i:] for i in range(n)]))
df = pd.DataFrame(data,columns=['sentence'])
df = df.dropna(thresh=1)

df['bigrams'] = df['sentence'].map(lambda x: find_ngrams(x.split(" "), 2))
bigrams = df['bigrams'].tolist()
bigrams = list(chain(*bigrams))
bigrams = [(x.lower(), y.lower()) for x,y in bigrams]
bigram_counts = Counter(bigrams)
bi=pd.Series(bigram_counts)
nbi=(bi/len(bi))
bivar=nbi.std()
print(1/bivar)

df['trigrams'] = df['sentence'].map(lambda x: find_ngrams(x.split(" "), 3))
trigrams = df['trigrams'].tolist()
trigrams = list(chain(*trigrams))
trigrams = [(x.lower(), y.lower(),z.lower()) for x,y,z in trigrams]
trigram_counts = Counter(trigrams)
tri=pd.Series(trigram_counts)
ntri=(tri/len(tri))
trivar=ntri.std()
print(1/trivar)

nr=bi.sum() 
print(nr)
print(len(bi))
dr=0
for i in range(len(bi)):
    xdr=((0.01*nr)-bi[i])*(bi[i]-1)
    if(xdr>=0):
        dr=dr+bi[i]
    else:
        dr=dr-bi[i]
print(dr)
print(dr/nr)

nr=tri.sum() 
print(nr)
print(len(tri))
dr=0
for i in range(len(tri)):
    xdr=((0.002*nr)-tri[i])*(tri[i]-1)
    if(xdr>=0):
        dr=dr+tri[i]
    else:
        dr=dr-tri[i]
print(dr)
print(dr/nr)

bi=bi.sort_values(ascending=False)
tri=tri.sort_values(ascending=False)
print((bi/len(bi)).head(20))
print((tri/len(tri)).head(20))
# Out:
# 497.2043806150385
# 1567.0118845765649
# 491
# 395
# 413
# 0.8411405295315683
# 443
# 416
# 339
# 0.7652370203160271
# a        woman       0.017722
#          man         0.017722
# on       a           0.017722
# in       a           0.017722
# man      is          0.015190
# on       the         0.012658
# man      and         0.010127
# in       the         0.010127
# the      stairs      0.007595
#          man         0.007595
# and      woman       0.007595
# with     a           0.007595
# holding  a           0.007595
# the      sidewalk    0.007595
# women    are         0.005063
# and      a           0.005063
# long     jumper      0.005063
# a        mesh        0.005063
# mesh     fence       0.005063
# in       an          0.005063
# dtype: float64
# on       the      sidewalk      0.007212
# man      and      woman         0.007212
# dressed  for      winter        0.004808
# while    leaning  on            0.004808
# closed   sign     and           0.004808
# a        closed   sign          0.004808
#          man      is            0.004808
# rowing   on       surfboards    0.004808
# is       holding  a             0.004808
# the      man      is            0.004808
# a        mesh     fence         0.004808
# and      looks    very          0.004808
# leaning  on       a             0.004808
# on       a        mesh          0.004808
# lake     while    leaning       0.004808
# a        long     jumper        0.004808
# up       the      stairs        0.004808
# stares   across   a             0.004808
# winter   stares   across        0.004808
# for      winter   stares        0.004808
# dtype: float64

# %%
data = gn['fullnopunc'].to_list()
def find_ngrams(input_list, n):
    return list(zip(*[input_list[i:] for i in range(n)]))
df = pd.DataFrame(data,columns=['sentence'])
df = df.dropna(thresh=1)

df['bigrams'] = df['sentence'].map(lambda x: find_ngrams(x.split(" "), 2))
bigrams = df['bigrams'].tolist()
bigrams = list(chain(*bigrams))
bigrams = [(x.lower(), y.lower()) for x,y in bigrams]
bigram_counts = Counter(bigrams)
bi=pd.Series(bigram_counts)
nbi=(bi/len(bi))
bivar=nbi.std()
print(1/bivar)

df['trigrams'] = df['sentence'].map(lambda x: find_ngrams(x.split(" "), 3))
trigrams = df['trigrams'].tolist()
trigrams = list(chain(*trigrams))
trigrams = [(x.lower(), y.lower(),z.lower()) for x,y,z in trigrams]
trigram_counts = Counter(trigrams)
tri=pd.Series(trigram_counts)
ntri=(tri/len(tri))
trivar=ntri.std()
print(1/trivar)

nr=bi.sum() 
print(nr)
print(len(bi))
dr=0
for i in range(len(bi)):
    xdr=((0.01*nr)-bi[i])*(bi[i]-1)
    if(xdr>=0):
        dr=dr+bi[i]
    else:
        dr=dr-bi[i]
print(dr)
print(dr/nr)

nr=tri.sum() 
print(nr)
print(len(tri))
dr=0
for i in range(len(tri)):
    xdr=((0.002*nr)-tri[i])*(tri[i]-1)
    if(xdr>=0):
        dr=dr+tri[i]
    else:
        dr=dr-tri[i]
print(dr)
print(dr/nr)

bi=bi.sort_values(ascending=False)
tri=tri.sort_values(ascending=False)
print((bi/len(bi)).head(20))
print((tri/len(tri)).head(20))
# Out:
# 620.1037274816345
# 2174.654254998249
# 1038
# 786
# 942
# 0.9075144508670521
# 934
# 861
# 682
# 0.7301927194860813
# in       a          0.025445
# a        man        0.020356
#          woman      0.015267
# on       a          0.012723
# in       the        0.010178
# man      is         0.010178
# at       a          0.008906
# a        young      0.008906
# of       a          0.008906
# young    man        0.007634
# with     a          0.007634
# a        red        0.006361
# man      wearing    0.006361
#          in         0.006361
# wearing  a          0.006361
# is       sitting    0.006361
# group    of         0.006361
# of       people     0.006361
# people   are        0.005089
# a        group      0.005089
# dtype: float64
# a         young     man       0.006969
# man       in        a         0.005807
#           wearing   a         0.004646
# a         man       is        0.004646
#           woman     in        0.004646
#           group     of        0.004646
# group     of        people    0.004646
# a         man       in        0.003484
# looking   in        a         0.003484
# woman     in        a         0.003484
# people    standing  at        0.002323
# standing  at        a         0.002323
# smoking   a         cigar     0.002323
# sitting   in        a         0.002323
# is        sitting   in        0.002323
# a         lot       of        0.002323
# young     man       waits     0.002323
# in        front     of        0.002323
# around    the       rink      0.002323
# skating   around    the       0.002323
# dtype: float64

# %%
data = gc['fullnopunc'].to_list()
def find_ngrams(input_list, n):
    return list(zip(*[input_list[i:] for i in range(n)]))
df = pd.DataFrame(data,columns=['sentence'])
df = df.dropna(thresh=1)

df['bigrams'] = df['sentence'].map(lambda x: find_ngrams(x.split(" "), 2))
bigrams = df['bigrams'].tolist()
bigrams = list(chain(*bigrams))
bigrams = [(x.lower(), y.lower()) for x,y in bigrams]
bigram_counts = Counter(bigrams)
bi=pd.Series(bigram_counts)
nbi=(bi/len(bi))
bivar=nbi.std()
print(1/bivar)

df['trigrams'] = df['sentence'].map(lambda x: find_ngrams(x.split(" "), 3))
trigrams = df['trigrams'].tolist()
trigrams = list(chain(*trigrams))
trigrams = [(x.lower(), y.lower(),z.lower()) for x,y,z in trigrams]
trigram_counts = Counter(trigrams)
tri=pd.Series(trigram_counts)
ntri=(tri/len(tri))
trivar=ntri.std()
print(1/trivar)

nr=bi.sum() 
print(nr)
print(len(bi))
dr=0
for i in range(len(bi)):
    xdr=((0.01*nr)-bi[i])*(bi[i]-1)
    if(xdr>=0):
        dr=dr+bi[i]
    else:
        dr=dr-bi[i]
print(dr)
print(dr/nr)

nr=tri.sum() 
print(nr)
print(len(tri))
dr=0
for i in range(len(tri)):
    xdr=((0.002*nr)-tri[i])*(tri[i]-1)
    if(xdr>=0):
        dr=dr+tri[i]
    else:
        dr=dr-tri[i]
print(dr)
print(dr/nr)

bi=bi.sort_values(ascending=False)
tri=tri.sort_values(ascending=False)
print((bi/len(bi)).head(20))
print((tri/len(tri)).head(20))
# Out:
# 403.47744181315846
# 1154.0280199151225
# 580
# 446
# 476
# 0.8206896551724138
# 530
# 486
# 376
# 0.7094339622641509
# in     a         0.033632
# a      man       0.026906
# man    in        0.015695
# and    a         0.013453
# a      woman     0.013453
# on     a         0.013453
# in     the       0.011211
# a      red       0.008969
#        blue      0.008969
# with   a         0.008969
#        his       0.008969
# of     a         0.008969
# the    man       0.008969
# man    is        0.006726
# in     front     0.006726
# front  of        0.006726
# a      small     0.006726
#        person    0.006726
# women  are       0.006726
# at     a         0.006726
# dtype: float64
# man    in       a           0.012346
# a      man      in          0.012346
# in     a        blue        0.006173
# woman  in       a           0.006173
# in     front    of          0.006173
# a      man      and         0.004115
#        person   is          0.004115
# and    a        name        0.004115
# suit   with     gold        0.004115
# a      suit     with        0.004115
# in     a        suit        0.004115
# while  others   stand       0.004115
# and    a        red         0.004115
# name   tag      gestures    0.004115
# group  of       people      0.004115
# a      group    of          0.004115
# child  in       a           0.004115
# is     pushing  a           0.004115
# man    is       pushing     0.004115
# red    jacket   is          0.004115
# dtype: float64

# %%
def find_ngrams(input_list, n):
    return list(zip(*[input_list[i:] for i in range(n)]))

data = glabel['fullnopunc'].to_list()
df = pd.DataFrame(data,columns=['sentence'])
df = df.dropna(thresh=1)
df['bigrams'] = df['sentence'].map(lambda x: find_ngrams(x.split(" "), 2))
bigrams = df['bigrams'].tolist()
bigrams = list(chain(*bigrams))
bigrams = [(x.lower(), y.lower()) for x,y in bigrams]
bigram_counts = Counter(bigrams)
bi=pd.Series(bigram_counts)

datae = ge['fullnopunc'].to_list()
dfe = pd.DataFrame(datae,columns=['sentence'])
dfe = dfe.dropna(thresh=1)
dfe['bigrams'] = dfe['sentence'].map(lambda x: find_ngrams(x.split(" "), 2))

datan = gn['fullnopunc'].to_list()
dfn = pd.DataFrame(datan,columns=['sentence'])
dfn = dfn.dropna(thresh=1)
dfn['bigrams'] = dfn['sentence'].map(lambda x: find_ngrams(x.split(" "), 2))

datac = gc['fullnopunc'].to_list()
dfc = pd.DataFrame(datac,columns=['sentence'])
dfc = dfc.dropna(thresh=1)
dfc['bigrams'] = dfc['sentence'].map(lambda x: find_ngrams(x.split(" "), 2))


dfb=pd.DataFrame(bi)
dfb['sentence'] = [' '.join(map(str,i)) for i in dfb.index.tolist()]
arrv=[]
arrsd=[]
for i in tqdm(range(len(dfb))):
    arr=[]
    c1=0
    c2=0
    c3=0
    s=dfb.iloc[i]['sentence']
    bg=s.split()
    for j in range(len(dfe)):
        x=dfe.iloc[j]['bigrams']
        for k in range(len(x)):
            if(bg==list(x[k])):
                c1=c1+1
    for j in range(len(dfn)):
        x=dfn.iloc[j]['bigrams']
        for k in range(len(x)):
            if(bg==list(x[k])):
                c2=c2+1
    for j in range(len(dfc)):
        x=dfc.iloc[j]['bigrams']
        for k in range(len(x)):
            if(bg==list(x[k])):
                c3=c3+1    
    if(c1+c2+c3>1):
        arr.append(c1)
        arr.append(c2)
        arr.append(c3)
        v=pd.Series(arr).var()
        sd=pd.Series(arr).std()
        arrv.append(v)
        arrsd.append(sd)
    else:
        arrv.append(0)
        arrsd.append(0)
gbgv=arrv
gbgstd=arrsd

print(len(df)/(pd.Series(arrsd).sum()+1))
# Out:
# HBox(children=(IntProgress(value=0, max=1450), HTML(value='')))
# 0.7928864448869397

# %%
def find_ngrams(input_list, n):
    return list(zip(*[input_list[i:] for i in range(n)]))

data = glabel['fullnopunc'].to_list()
df = pd.DataFrame(data,columns=['sentence'])
df = df.dropna(thresh=1)
df['trigrams'] = df['sentence'].map(lambda x: find_ngrams(x.split(" "), 3))
trigrams = df['trigrams'].tolist()
trigrams = list(chain(*trigrams))
trigrams = [(x.lower(), y.lower(),z.lower()) for x,y,z in trigrams]
trigram_counts = Counter(trigrams)
tri=pd.Series(trigram_counts)

datae = ge['fullnopunc'].to_list()
dfe = pd.DataFrame(datae,columns=['sentence'])
dfe = dfe.dropna(thresh=1)
dfe['trigrams'] = dfe['sentence'].map(lambda x: find_ngrams(x.split(" "), 3))

datan = gn['fullnopunc'].to_list()
dfn = pd.DataFrame(datan,columns=['sentence'])
dfn = dfn.dropna(thresh=1)
dfn['trigrams'] = dfn['sentence'].map(lambda x: find_ngrams(x.split(" "), 3))

datac = gc['fullnopunc'].to_list()
dfc = pd.DataFrame(datac,columns=['sentence'])
dfc = dfc.dropna(thresh=1)
dfc['trigrams'] = dfc['sentence'].map(lambda x: find_ngrams(x.split(" "), 3))

dfb=pd.DataFrame(tri)
dfb['sentence'] = [' '.join(map(str,i)) for i in dfb.index.tolist()]
arrv=[]
arrsd=[]
for i in tqdm(range(len(dfb))):
    arr=[]
    c1=0
    c2=0
    c3=0
    s=dfb.iloc[i]['sentence']
    bg=s.split()
    for j in range(len(dfe)):
        x=dfe.iloc[j]['trigrams']
        for k in range(len(x)):
            if(bg==list(x[k])):
                c1=c1+1
    for j in range(len(dfn)):
        x=dfn.iloc[j]['trigrams']
        for k in range(len(x)):
            if(bg==list(x[k])):
                c2=c2+1
    for j in range(len(dfc)):
        x=dfc.iloc[j]['trigrams']
        for k in range(len(x)):
            if(bg==list(x[k])):
                c3=c3+1    
    if(c1+c2+c3>1):
        arr.append(c1)
        arr.append(c2)
        arr.append(c3)
        v=pd.Series(arr).var()
        sd=pd.Series(arr).std()
        arrv.append(v)
        arrsd.append(sd)
    else:
        arrv.append(0)
        arrsd.append(0)
gtgv=arrv
gtgstd=arrsd

print(len(df)/(pd.Series(arrsd).sum()+1))
# Out:
# HBox(children=(IntProgress(value=0, max=1685), HTML(value='')))
# 1.7212598447683867

# %%
glearr=[]
glnarr=[]
glcarr=[]

df = pd.DataFrame(columns=['p', 'h', 'label'], data=df_testgood[['sentence1','sentence2','gold_label']].values)
df['p'] = df['p'].str.replace("'", "")
df['p'] = df['p'].str.replace(".", "")
df['p'] = df['p'].str.replace(",", "")
df['h'] = df['h'].str.replace("'", "")
df['h'] = df['h'].str.replace(".", "")
df['h'] = df['h'].str.replace(",", "")

dfe = df[df['label']=='entailment']
dfn = df[df['label']=='neutral']
dfc = df[df['label']=='contradiction']

for i in tqdm(range(len(dfe))):         
     glearr.append(abs((len((dfe.iloc[i]['p']).split()))-(len((dfe.iloc[i]['h']).split()))))
print(pd.Series(glearr).mean())
print(len(glearr)/(pd.Series(glearr).sum()+1))
print(pd.Series(glearr).std()/len(dfe))


for i in tqdm(range(len(dfn))):         
     glnarr.append(abs((len((dfn.iloc[i]['p']).split()))-(len((dfn.iloc[i]['h']).split()))))
print(pd.Series(glnarr).mean())
print(len(glnarr)/(pd.Series(glnarr).sum()+1))
print(pd.Series(glnarr).std()/len(dfn))



for i in tqdm(range(len(dfc))):         
     glcarr.append(abs((len((dfc.iloc[i]['p']).split()))-(len((dfc.iloc[i]['h']).split()))))
print(pd.Series(glcarr).mean())
print(len(glcarr)/(pd.Series(glcarr).sum()+1))
print(pd.Series(glcarr).std()/len(dfc))
# Out:
# HBox(children=(IntProgress(value=0, max=24), HTML(value='')))
# 5.375
# 0.18461538461538463
# 0.20032148829193933
# HBox(children=(IntProgress(value=0, max=52), HTML(value='')))
# 6.8076923076923075
# 0.14647887323943662
# 0.12257855722284836
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# 9.6
# 0.1037344398340249
# 0.3485206832695395

# %%
#------------------------------------------------------------------------------------------
